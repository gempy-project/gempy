# %% [markdown]
# # Chapter 1: GemPy Basic
#
# In this first example, we will show how to construct a first basic model and the main objects and functions. First we import gempy:

# %%
# These two lines are necessary only if gempy is not installed
import sys, os
sys.path.append("../..")

# Importing gempy
import gempy as gp

# Embedding matplotlib figures into the notebooks
# %matplotlib inline

# Aux imports
import numpy as np
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# All data get stored in a python object InputData.  This object can be easily stored in a Python pickle. However, these files have the limitation that all dependecies must have the same versions as those when the pickle were created. For these reason to have more stable tutorials we will generate the InputData from raw data---i.e. csv files exported from Geomodeller.
#
# These csv files can be found in the input_data folder in the root folder of GemPy. These tables contains uniquely the XYZ (and poles, azimuth and polarity in the foliation case) as well as their respective formation name (but not necessary the formation order).

# %%
# Importing the data from csv files and settign extent and resolution
geo_data = gp.create_data([0,2000,0,2000,-2000,0],[ 60,60,60],
                         path_o = os.pardir+"/input_data/FabLessPoints_Foliations.csv",
                         path_i = os.pardir+"/input_data/FabLessPoints_Points.csv")
# Out:
# here
# there

# %%
geo_data.interfaces.tail()
# Out:
#          X       Y      Z           formation         series X_std Y_std  \
# 35  1900.0  1000.0 -800.0  SecondaryReservoir  Default serie   NaN   NaN
# 36   900.0  1000.0 -650.0  SecondaryReservoir  Default serie   NaN   NaN
# 37   600.0  1000.0 -550.0  SecondaryReservoir  Default serie   NaN   NaN
# 38  1300.0  1000.0 -600.0  SecondaryReservoir  Default serie   NaN   NaN
# 39     NaN     NaN    NaN            basement        Default   NaN   NaN
#
#    Z_std  order_series isFault  formation_number  \
# 35   NaN           1.0   False               5.0
# 36   NaN           1.0   False               5.0
# 37   NaN           1.0   False               5.0
# 38   NaN           1.0   False               5.0
# 39   NaN           1.0     NaN               6.0
#
#                            annotations
# 35  ${\bf{x}}_{\alpha \,{\bf{5.0}},2}$
# 36  ${\bf{x}}_{\alpha \,{\bf{5.0}},3}$
# 37  ${\bf{x}}_{\alpha \,{\bf{5.0}},4}$
# 38  ${\bf{x}}_{\alpha \,{\bf{5.0}},5}$
# 39  ${\bf{x}}_{\alpha \,{\bf{6.0}},0}$

# %%
# Assigning series to formations as well as their order (timewise)
gp.set_series(geo_data, {"fault":'MainFault', 
                      "Rest": ('SecondaryReservoir','Seal', 'Reservoir', 'Overlying'), 
                               },
                       order_series = ["fault", 'Rest'],
                       order_formations=['MainFault', 
                                         'SecondaryReservoir', 'Seal','Reservoir', 'Overlying',
                                         ])
# Out:
# there
# there

# %%
geo_data.interfaces.tail()
# Out:
#          X       Y       Z  formation series X_std Y_std Z_std  order_series  \
# 35  1000.0  1000.0 -1300.0  Overlying   Rest   NaN   NaN   NaN             2
# 36  1900.0  1000.0 -1600.0  Overlying   Rest   NaN   NaN   NaN             2
# 37   300.0  1000.0 -1250.0  Overlying   Rest   NaN   NaN   NaN             2
# 38   600.0  1000.0 -1350.0  Overlying   Rest   NaN   NaN   NaN             2
# 39     NaN     NaN     NaN   basement   Rest   NaN   NaN   NaN             2
#
#     isFault  formation_number                       annotations
# 35    False                 5  ${\bf{x}}_{\alpha \,{\bf{5}},4}$
# 36    False                 5  ${\bf{x}}_{\alpha \,{\bf{5}},5}$
# 37    False                 5  ${\bf{x}}_{\alpha \,{\bf{5}},6}$
# 38    False                 5  ${\bf{x}}_{\alpha \,{\bf{5}},7}$
# 39    False                 6  ${\bf{x}}_{\alpha \,{\bf{6}},0}$

# %%
gp.get_series(geo_data)
# Out:
#        fault                Rest
# 0  MainFault  SecondaryReservoir
# 1        NaN                Seal
# 2        NaN           Reservoir
# 3        NaN           Overlying
# 4        NaN            basement

# %%
gp.get_sequential_pile(geo_data)

# %%
gp.plot_data(geo_data)

# %%
gp.plot_data_3D(geo_data)

# %%
interp_data = gp.InterpolatorData(geo_data, compile_theano=True, u_grade=[0,1])
# Out:
# Compiling theano function...
# Compilation Done!
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float32
# Number of faults:  1

# %%
sol = gp.compute_model(interp_data)

# %%
gp.plot_section(geo_data, sol[0][0], 30, plot_data=True)
# Out:
# [[ 6.          6.          6.         ...,  6.          6.          6.        ]
#  [ 6.          6.          6.         ...,  6.          6.          6.        ]
#  [ 6.          6.          6.         ...,  6.          6.          6.        ]
#  ...,
#  [ 2.01486492  2.00524759  2.00182676 ...,  2.          2.          2.        ]
#  [ 2.00323343  2.00118351  2.00042772 ...,  2.          2.          2.        ]
#  [ 2.00074935  2.00028467  2.00010633 ...,  2.          2.          2.        ]] <class 'numpy.ndarray'>

# %%
gp.plot_scalar_field(geo_data, sol[0][0], 30)

# %%
ver, sim = gp.get_surfaces(interp_data, sol[0][1], sol[1][1])

# %%
gp.plot_surfaces_3D(geo_data, ver, sim)
