# %% [markdown]
# # Chapter 1: GemPy Basic
#
# In this first example, we will show how to construct a first basic model and the main objects and functions. First we import gempy:

# %%
# These two lines are necessary only if gempy is not installed
import sys, os
sys.path.append("../..")

# Importing gempy
import gempy as gp

# Embedding matplotlib figures into the notebooks
# %matplotlib inline

# Aux imports
import numpy as np
import pandas as pn
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# Importing the data from csv files and settign extent and resolution
geo_data = gp.create_data([0,2000,0,2000,-2000,0],[ 20,20,20],
                         path_o = os.pardir+"/input_data/FabLessPoints_Foliations.csv",
                         path_i = os.pardir+"/input_data/FabLessPoints_Points.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-cc69caebc223> in <module>()
#       2 geo_data = gp.create_data([0,2000,0,2000,-2000,0],[ 20,20,20],
#       3                          path_o = os.pardir+"/input_data/FabLessPoints_Foliations.csv",
# ----> 4                          path_i = os.pardir+"/input_data/FabLessPoints_Points.csv")
#
# ~/PycharmProjects/gempy/gempy/gempy_front.py in create_data(extent, resolution, **kwargs)
#     121     """
#     122
# --> 123     return InputData(extent, resolution, **kwargs)
#     124
#     125
#
# ~/PycharmProjects/gempy/gempy/data_management.py in __init__(self, extent, resolution, path_i, path_o, path_f, **kwargs)
#      98
#      99         # If not provided set default series
# --> 100         self.series = self.update_df()
#     101
#     102         # Compute gradients given azimuth and dips to plot data
#
# ~/PycharmProjects/gempy/gempy/data_management.py in update_df(self, series_distribution, order)
#     698         self.reset_indices()
#     699
# --> 700         self.set_formation_number()
#     701
#     702         self.order_table()
#
# ~/PycharmProjects/gempy/gempy/data_management.py in set_formation_number(self, formation_order)
#     755             pass
#     756
# --> 757         self.set_basement()
#     758         #self.order_table()
#     759
#
# ~/PycharmProjects/gempy/gempy/data_management.py in set_basement(self)
#     136             columns = {'X': self.extent[0], 'Y': self.extent[2], 'Z': self.extent[4], 'formation':'basement', 'order_series': n_series, 'formation_number': n_formation, 'series': 'Default'}
#     137             for key in columns:
# --> 138                 self.interfaces.ix[l, str(key)] = columns[key]
#     139                 self.order_table()
#     140             print('here')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     606                 # scalar
#     607                 for item in labels:
# --> 608                     setter(item, value)
#     609
#     610         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in setter(item, v)
#     531                     s._consolidate_inplace()
#     532                     s = s.copy()
# --> 533                     s._data = s._data.setitem(indexer=pi, value=v)
#     534                     s._maybe_update_cacher(clear=True)
#     535
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in setitem(self, **kwargs)
#    3439
#    3440     def setitem(self, **kwargs):
# -> 3441         return self.apply('setitem', **kwargs)
#    3442
#    3443     def putmask(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in setitem(self, indexer, value, mgr)
#     899         # set
#     900         else:
# --> 901             values[indexer] = value
#     902
#     903         # coerce and try to infer the dtypes of the result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/categorical.py in __setitem__(self, key, value)
#    1868         # something to np.nan
#    1869         if len(to_add) and not isna(to_add).all():
# -> 1870             raise ValueError("Cannot setitem on a Categorical with a new "
#    1871                              "category, set the categories first")
#    1872
#
# ValueError: Cannot setitem on a Categorical with a new category, set the categories first

# %%
gp.get_data(geo_data)
# Out:
#                       G_x           G_y       G_z        X       Y         Z  \
# interfaces   0        NaN           NaN       NaN   800.00   200.0 -1400.000
#              1        NaN           NaN       NaN   800.00  1800.0 -1400.000
#              2        NaN           NaN       NaN   600.00  1000.0 -1050.000
#              3        NaN           NaN       NaN   300.00  1000.0  -950.000
#              4        NaN           NaN       NaN  2000.00  1000.0 -1275.000
#              5        NaN           NaN       NaN  1900.00  1000.0 -1300.000
#              6        NaN           NaN       NaN  1300.00  1000.0 -1100.000
#              7        NaN           NaN       NaN  1600.00  1000.0 -1200.000
#              8        NaN           NaN       NaN  1750.00  1000.0 -1250.000
#              9        NaN           NaN       NaN  1000.00    25.0 -1050.000
#              10       NaN           NaN       NaN  1000.00   100.0 -1100.000
#              11       NaN           NaN       NaN  1000.00  1975.0 -1050.000
#              12       NaN           NaN       NaN  1000.00  1900.0 -1100.000
#              13       NaN           NaN       NaN  1150.00  1000.0 -1050.000
#              14       NaN           NaN       NaN   600.00  1000.0  -650.000
#              15       NaN           NaN       NaN  1300.00  1000.0  -700.000
#              16       NaN           NaN       NaN  1600.00  1000.0  -800.000
#              17       NaN           NaN       NaN  1900.00  1000.0  -900.000
#              18       NaN           NaN       NaN  2000.00  1000.0  -875.000
#              19       NaN           NaN       NaN   900.00  1000.0  -750.000
#              20       NaN           NaN       NaN   600.00  1000.0 -1350.000
#              21       NaN           NaN       NaN   300.00  1000.0 -1250.000
#              22       NaN           NaN       NaN  2000.00  1000.0 -1575.000
#              23       NaN           NaN       NaN  1300.00  1000.0 -1400.000
#              24       NaN           NaN       NaN  1600.00  1000.0 -1500.000
#              25       NaN           NaN       NaN  1750.00  1000.0 -1550.000
#              26       NaN           NaN       NaN  1000.00  1000.0 -1300.000
#              27       NaN           NaN       NaN  1900.00  1000.0 -1600.000
#              28       NaN           NaN       NaN  1000.00  1000.0 -1000.000
#              29       NaN           NaN       NaN   900.00  1000.0 -1300.000
#              30       NaN           NaN       NaN  1100.00  1000.0  -700.000
#              31       NaN           NaN       NaN  1200.00  1000.0  -400.000
#              32       NaN           NaN       NaN   800.00  1000.0 -1600.000
#              33       NaN           NaN       NaN  2000.00  1000.0  -775.000
#              34       NaN           NaN       NaN  1600.00  1000.0  -700.000
#              35       NaN           NaN       NaN  1900.00  1000.0  -800.000
#              36       NaN           NaN       NaN   900.00  1000.0  -650.000
#              37       NaN           NaN       NaN   600.00  1000.0  -550.000
#              38       NaN           NaN       NaN  1300.00  1000.0  -600.000
#              39       NaN           NaN       NaN     0.00     0.0 -2000.000
# orientations 0   0.316229  1.000000e-07  0.948683  1450.00  1000.0 -1150.000
#              1  -0.948683  1.000000e-07  0.316229   917.45  1000.0 -1135.398
#
#                  azimuth     dip           formation  formation_number  \
# interfaces   0       NaN     NaN           Reservoir                 1
#              1       NaN     NaN           Reservoir                 1
#              2       NaN     NaN           Reservoir                 1
#              3       NaN     NaN           Reservoir                 1
#              4       NaN     NaN           Reservoir                 1
#              5       NaN     NaN           Reservoir                 1
#              6       NaN     NaN           Reservoir                 1
#              7       NaN     NaN           Reservoir                 1
#              8       NaN     NaN           Reservoir                 1
#              9       NaN     NaN           Reservoir                 1
#              10      NaN     NaN           Reservoir                 1
#              11      NaN     NaN           Reservoir                 1
#              12      NaN     NaN           Reservoir                 1
#              13      NaN     NaN           Reservoir                 1
#              14      NaN     NaN                Seal                 2
#              15      NaN     NaN                Seal                 2
#              16      NaN     NaN                Seal                 2
#              17      NaN     NaN                Seal                 2
#              18      NaN     NaN                Seal                 2
#              19      NaN     NaN                Seal                 2
#              20      NaN     NaN           Overlying                 3
#              21      NaN     NaN           Overlying                 3
#              22      NaN     NaN           Overlying                 3
#              23      NaN     NaN           Overlying                 3
#              24      NaN     NaN           Overlying                 3
#              25      NaN     NaN           Overlying                 3
#              26      NaN     NaN           Overlying                 3
#              27      NaN     NaN           Overlying                 3
#              28      NaN     NaN           MainFault                 4
#              29      NaN     NaN           MainFault                 4
#              30      NaN     NaN           MainFault                 4
#              31      NaN     NaN           MainFault                 4
#              32      NaN     NaN           MainFault                 4
#              33      NaN     NaN  SecondaryReservoir                 5
#              34      NaN     NaN  SecondaryReservoir                 5
#              35      NaN     NaN  SecondaryReservoir                 5
#              36      NaN     NaN  SecondaryReservoir                 5
#              37      NaN     NaN  SecondaryReservoir                 5
#              38      NaN     NaN  SecondaryReservoir                 5
#              39      NaN     NaN            basement                 6
# orientations 0      90.0  18.435           Reservoir                 1
#              1     270.0  71.565           MainFault                 4
#
#                  isFault  order_series  polarity         series
# interfaces   0     False             1       NaN  Default serie
#              1     False             1       NaN  Default serie
#              2     False             1       NaN  Default serie
#              3     False             1       NaN  Default serie
#              4     False             1       NaN  Default serie
#              5     False             1       NaN  Default serie
#              6     False             1       NaN  Default serie
#              7     False             1       NaN  Default serie
#              8     False             1       NaN  Default serie
#              9     False             1       NaN  Default serie
#              10    False             1       NaN  Default serie
#              11    False             1       NaN  Default serie
#              12    False             1       NaN  Default serie
#              13    False             1       NaN  Default serie
#              14    False             1       NaN  Default serie
#              15    False             1       NaN  Default serie
#              16    False             1       NaN  Default serie
#              17    False             1       NaN  Default serie
#              18    False             1       NaN  Default serie
#              19    False             1       NaN  Default serie
#              20    False             1       NaN  Default serie
#              21    False             1       NaN  Default serie
#              22    False             1       NaN  Default serie
#              23    False             1       NaN  Default serie
#              24    False             1       NaN  Default serie
#              25    False             1       NaN  Default serie
#              26    False             1       NaN  Default serie
#              27    False             1       NaN  Default serie
#              28    False             1       NaN  Default serie
#              29    False             1       NaN  Default serie
#              30    False             1       NaN  Default serie
#              31    False             1       NaN  Default serie
#              32    False             1       NaN  Default serie
#              33    False             1       NaN  Default serie
#              34    False             1       NaN  Default serie
#              35    False             1       NaN  Default serie
#              36    False             1       NaN  Default serie
#              37    False             1       NaN  Default serie
#              38    False             1       NaN  Default serie
#              39     True             1       NaN        Default
# orientations 0     False             1       1.0  Default serie
#              1     False             1       1.0  Default serie

# %%
geo_data.interactive_df_open(itype='interfaces')
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defaultColumnWidth': 150, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': True, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 15, 'minVisibleRows': 8, 'sortable': True, 'filterable': True, 'highlightSelectedCell': False, 'highlightSelectedRow': True}, precision=5, show_toolbar=True)

# %%
n_df = geo_data.interactive_df_get_changed_df(only_selected=False)

# %%
n_df
# Out:
#                       G_x    G_y       G_z       X     Y       Z azimuth  \
# interfaces   0        NaN    NaN       NaN     800   200   -1400     NaN
#              1        NaN    NaN       NaN     800  1800   -1400     NaN
#              2        NaN    NaN       NaN     600  1000   -1050     NaN
#              3        NaN    NaN       NaN     300  1000    -950     NaN
#              4        NaN    NaN       NaN    2000  1000   -1275     NaN
#              5        NaN    NaN       NaN    1900  1000   -1300     NaN
#              6        NaN    NaN       NaN    1300  1000   -1100     NaN
#              7        NaN    NaN       NaN    1600  1000   -1200     NaN
#              8        NaN    NaN       NaN    1750  1000   -1250     NaN
#              9        NaN    NaN       NaN    1000    25   -1050     NaN
#              10       NaN    NaN       NaN    1000   100   -1100     NaN
#              11       NaN    NaN       NaN    1000  1975   -1050     NaN
#              12       NaN    NaN       NaN    1000  1900   -1100     NaN
#              13       NaN    NaN       NaN    1150  1000   -1050     NaN
#              14       NaN    NaN       NaN     600  1000    -650     NaN
#              15       NaN    NaN       NaN    1300  1000    -700     NaN
#              16       NaN    NaN       NaN    1600  1000    -800     NaN
#              17       NaN    NaN       NaN    1900  1000    -900     NaN
#              18       NaN    NaN       NaN    2000  1000    -875     NaN
#              19       NaN    NaN       NaN     900  1000    -750     NaN
#              20       NaN    NaN       NaN     600  1000   -1350     NaN
#              21       NaN    NaN       NaN     300  1000   -1250     NaN
#              22       NaN    NaN       NaN    2000  1000   -1575     NaN
#              23       NaN    NaN       NaN    1300  1000   -1400     NaN
#              24       NaN    NaN       NaN    1600  1000   -1500     NaN
#              25       NaN    NaN       NaN    1750  1000   -1550     NaN
#              26       NaN    NaN       NaN    1000  1000   -1300     NaN
#              27       NaN    NaN       NaN    1900  1000   -1600     NaN
#              28       NaN    NaN       NaN    1000  1000   -1000     NaN
#              29       NaN    NaN       NaN     900  1000   -1300     NaN
#              30       NaN    NaN       NaN    1100  1000    -700     NaN
#              31       NaN    NaN       NaN    1200  1000    -400     NaN
#              32       NaN    NaN       NaN     800  1000   -1600     NaN
#              33       NaN    NaN       NaN    2000  1000    -775     NaN
#              34       NaN    NaN       NaN    1600  1000    -700     NaN
#              35       NaN    NaN       NaN    1900  1000    -800     NaN
#              36       NaN    NaN       NaN     900  1000    -650     NaN
#              37       NaN    NaN       NaN     600  1000    -550     NaN
#              38       NaN    NaN       NaN    1300  1000    -600     NaN
#              39       NaN    NaN       NaN     NaN   NaN     NaN     NaN
# orientations 0   0.316229  1e-07  0.948683    1450  1000   -1150      90
#              1  -0.948683  1e-07  0.316229  917.45  1000 -1135.4     270
#
#                     dip           formation polarity         series
# interfaces   0      NaN           Reservoir      NaN  Default serie
#              1      NaN           Reservoir      NaN  Default serie
#              2      NaN           Reservoir      NaN  Default serie
#              3      NaN           Reservoir      NaN  Default serie
#              4      NaN           Reservoir      NaN  Default serie
#              5      NaN           Reservoir      NaN  Default serie
#              6      NaN           Reservoir      NaN  Default serie
#              7      NaN           Reservoir      NaN  Default serie
#              8      NaN           Reservoir      NaN  Default serie
#              9      NaN           Reservoir      NaN  Default serie
#              10     NaN           Reservoir      NaN  Default serie
#              11     NaN           Reservoir      NaN  Default serie
#              12     NaN           Reservoir      NaN  Default serie
#              13     NaN           Reservoir      NaN  Default serie
#              14     NaN                Seal      NaN  Default serie
#              15     NaN                Seal      NaN  Default serie
#              16     NaN                Seal      NaN  Default serie
#              17     NaN                Seal      NaN  Default serie
#              18     NaN                Seal      NaN  Default serie
#              19     NaN                Seal      NaN  Default serie
#              20     NaN           Overlying      NaN  Default serie
#              21     NaN           Overlying      NaN  Default serie
#              22     NaN           Overlying      NaN  Default serie
#              23     NaN           Overlying      NaN  Default serie
#              24     NaN           Overlying      NaN  Default serie
#              25     NaN           Overlying      NaN  Default serie
#              26     NaN           Overlying      NaN  Default serie
#              27     NaN           Overlying      NaN  Default serie
#              28     NaN           MainFault      NaN  Default serie
#              29     NaN           MainFault      NaN  Default serie
#              30     NaN           MainFault      NaN  Default serie
#              31     NaN           MainFault      NaN  Default serie
#              32     NaN           MainFault      NaN  Default serie
#              33     NaN  SecondaryReservoir      NaN  Default serie
#              34     NaN  SecondaryReservoir      NaN  Default serie
#              35     NaN  SecondaryReservoir      NaN  Default serie
#              36     NaN  SecondaryReservoir      NaN  Default serie
#              37     NaN  SecondaryReservoir      NaN  Default serie
#              38     NaN  SecondaryReservoir      NaN  Default serie
#              39     NaN            basement      NaN        Default
# orientations 0   18.435           Reservoir        1  Default serie
#              1   71.565           MainFault        1  Default serie

# %%
geo_data.set_new_df(n_df)
# Out:
# there
# there
#          X       Y         Z       G_x           G_y       G_z     dip  \
# 0  1450.00  1000.0 -1150.000  0.316229  1.000000e-07  0.948683  18.435
# 1   917.45  1000.0 -1135.398 -0.948683  1.000000e-07  0.316229  71.565
#
#    azimuth  polarity  formation         series  order_series  isFault  \
# 0     90.0       1.0  Reservoir  Default serie             1    False
# 1    270.0       1.0  MainFault  Default serie             1    False
#
#    formation_number                      annotations
# 0                 1  ${\bf{x}}_{\beta \,{\bf{1}},0}$
# 1                 2  ${\bf{x}}_{\beta \,{\bf{2}},0}$
# there
#           X       Y         Z       G_x           G_y       G_z     dip  \
# 0    800.00   200.0 -1400.000       NaN           NaN       NaN     NaN
# 22   800.00  1800.0 -1400.000       NaN           NaN       NaN     NaN
# 23   600.00  1000.0 -1050.000       NaN           NaN       NaN     NaN
# 24   300.00  1000.0  -950.000       NaN           NaN       NaN     NaN
# 25  2000.00  1000.0 -1275.000       NaN           NaN       NaN     NaN
# 26  1900.00  1000.0 -1300.000       NaN           NaN       NaN     NaN
# 27  1300.00  1000.0 -1100.000       NaN           NaN       NaN     NaN
# 28  1600.00  1000.0 -1200.000       NaN           NaN       NaN     NaN
# 29  1750.00  1000.0 -1250.000       NaN           NaN       NaN     NaN
# 30  1450.00  1000.0 -1150.000  0.316229  1.000000e-07  0.948683  18.435
# 31  1000.00    25.0 -1050.000       NaN           NaN       NaN     NaN
# 32  1000.00  1975.0 -1050.000       NaN           NaN       NaN     NaN
# 33  1000.00  1900.0 -1100.000       NaN           NaN       NaN     NaN
# 34  1150.00  1000.0 -1050.000       NaN           NaN       NaN     NaN
# 40  1000.00   100.0 -1100.000       NaN           NaN       NaN     NaN
# 11  2000.00  1000.0  -775.000       NaN           NaN       NaN     NaN
# 12  1600.00  1000.0  -700.000       NaN           NaN       NaN     NaN
# 13  1900.00  1000.0  -800.000       NaN           NaN       NaN     NaN
# 14   900.00  1000.0  -650.000       NaN           NaN       NaN     NaN
# 15   600.00  1000.0  -550.000       NaN           NaN       NaN     NaN
# 16  1300.00  1000.0  -600.000       NaN           NaN       NaN     NaN
# 1   1300.00  1000.0 -1400.000       NaN           NaN       NaN     NaN
# 2   1600.00  1000.0 -1500.000       NaN           NaN       NaN     NaN
# 3   1750.00  1000.0 -1550.000       NaN           NaN       NaN     NaN
# 4   1000.00  1000.0 -1300.000       NaN           NaN       NaN     NaN
# 5   1900.00  1000.0 -1600.000       NaN           NaN       NaN     NaN
# 18  2000.00  1000.0 -1575.000       NaN           NaN       NaN     NaN
# 19   300.00  1000.0 -1250.000       NaN           NaN       NaN     NaN
# 20   600.00  1000.0 -1350.000       NaN           NaN       NaN     NaN
# 21   900.00  1000.0  -750.000       NaN           NaN       NaN     NaN
# 35   600.00  1000.0  -650.000       NaN           NaN       NaN     NaN
# 36  1300.00  1000.0  -700.000       NaN           NaN       NaN     NaN
# 37  1600.00  1000.0  -800.000       NaN           NaN       NaN     NaN
# 38  1900.00  1000.0  -900.000       NaN           NaN       NaN     NaN
# 39  2000.00  1000.0  -875.000       NaN           NaN       NaN     NaN
# 6   1000.00  1000.0 -1000.000       NaN           NaN       NaN     NaN
# 7    900.00  1000.0 -1300.000       NaN           NaN       NaN     NaN
# 8   1100.00  1000.0  -700.000       NaN           NaN       NaN     NaN
# 9   1200.00  1000.0  -400.000       NaN           NaN       NaN     NaN
# 10   800.00  1000.0 -1600.000       NaN           NaN       NaN     NaN
# 41   917.45  1000.0 -1135.398 -0.948683  1.000000e-07  0.316229  71.565
# 17      NaN     NaN       NaN       NaN           NaN       NaN     NaN
#
#     azimuth  polarity           formation         series  order_series  \
# 0       NaN       NaN           Reservoir  Default serie             1
# 22      NaN       NaN           Reservoir  Default serie             1
# 23      NaN       NaN           Reservoir  Default serie             1
# 24      NaN       NaN           Reservoir  Default serie             1
# 25      NaN       NaN           Reservoir  Default serie             1
# 26      NaN       NaN           Reservoir  Default serie             1
# 27      NaN       NaN           Reservoir  Default serie             1
# 28      NaN       NaN           Reservoir  Default serie             1
# 29      NaN       NaN           Reservoir  Default serie             1
# 30     90.0       1.0           Reservoir  Default serie             1
# 31      NaN       NaN           Reservoir  Default serie             1
# 32      NaN       NaN           Reservoir  Default serie             1
# 33      NaN       NaN           Reservoir  Default serie             1
# 34      NaN       NaN           Reservoir  Default serie             1
# 40      NaN       NaN           Reservoir  Default serie             1
# 11      NaN       NaN  SecondaryReservoir  Default serie             1
# 12      NaN       NaN  SecondaryReservoir  Default serie             1
# 13      NaN       NaN  SecondaryReservoir  Default serie             1
# 14      NaN       NaN  SecondaryReservoir  Default serie             1
# 15      NaN       NaN  SecondaryReservoir  Default serie             1
# 16      NaN       NaN  SecondaryReservoir  Default serie             1
# 1       NaN       NaN           Overlying  Default serie             1
# 2       NaN       NaN           Overlying  Default serie             1
# 3       NaN       NaN           Overlying  Default serie             1
# 4       NaN       NaN           Overlying  Default serie             1
# 5       NaN       NaN           Overlying  Default serie             1
# 18      NaN       NaN           Overlying  Default serie             1
# 19      NaN       NaN           Overlying  Default serie             1
# 20      NaN       NaN           Overlying  Default serie             1
# 21      NaN       NaN                Seal  Default serie             1
# 35      NaN       NaN                Seal  Default serie             1
# 36      NaN       NaN                Seal  Default serie             1
# 37      NaN       NaN                Seal  Default serie             1
# 38      NaN       NaN                Seal  Default serie             1
# 39      NaN       NaN                Seal  Default serie             1
# 6       NaN       NaN           MainFault  Default serie             1
# 7       NaN       NaN           MainFault  Default serie             1
# 8       NaN       NaN           MainFault  Default serie             1
# 9       NaN       NaN           MainFault  Default serie             1
# 10      NaN       NaN           MainFault  Default serie             1
# 41    270.0       1.0           MainFault  Default serie             1
# 17      NaN       NaN            basement  Default serie             1
#
#     isFault  formation_number                       annotations
# 0     False                 1   ${\bf{x}}_{\beta \,{\bf{1}},0}$
# 22    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},1}$
# 23    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},2}$
# 24    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},3}$
# 25    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},4}$
# 26    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},5}$
# 27    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},6}$
# 28    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},7}$
# 29    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},8}$
# 30    False                 1   ${\bf{x}}_{\beta \,{\bf{1}},9}$
# 31    False                 1  ${\bf{x}}_{\beta \,{\bf{1}},10}$
# 32    False                 1  ${\bf{x}}_{\beta \,{\bf{1}},11}$
# 33    False                 1  ${\bf{x}}_{\beta \,{\bf{1}},12}$
# 34    False                 1  ${\bf{x}}_{\beta \,{\bf{1}},13}$
# 40    False                 1  ${\bf{x}}_{\beta \,{\bf{1}},14}$
# 11    False                 2   ${\bf{x}}_{\beta \,{\bf{2}},0}$
# 12    False                 2   ${\bf{x}}_{\beta \,{\bf{2}},1}$
# 13    False                 2   ${\bf{x}}_{\beta \,{\bf{2}},2}$
# 14    False                 2   ${\bf{x}}_{\beta \,{\bf{2}},3}$
# 15    False                 2   ${\bf{x}}_{\beta \,{\bf{2}},4}$
# 16    False                 2   ${\bf{x}}_{\beta \,{\bf{2}},5}$
# 1     False                 3   ${\bf{x}}_{\beta \,{\bf{3}},0}$
# 2     False                 3   ${\bf{x}}_{\beta \,{\bf{3}},1}$
# 3     False                 3   ${\bf{x}}_{\beta \,{\bf{3}},2}$
# 4     False                 3   ${\bf{x}}_{\beta \,{\bf{3}},3}$
# 5     False                 3   ${\bf{x}}_{\beta \,{\bf{3}},4}$
# 18    False                 3   ${\bf{x}}_{\beta \,{\bf{3}},5}$
# 19    False                 3   ${\bf{x}}_{\beta \,{\bf{3}},6}$
# 20    False                 3   ${\bf{x}}_{\beta \,{\bf{3}},7}$
# 21    False                 4   ${\bf{x}}_{\beta \,{\bf{4}},0}$
# 35    False                 4   ${\bf{x}}_{\beta \,{\bf{4}},1}$
# 36    False                 4   ${\bf{x}}_{\beta \,{\bf{4}},2}$
# 37    False                 4   ${\bf{x}}_{\beta \,{\bf{4}},3}$
# 38    False                 4   ${\bf{x}}_{\beta \,{\bf{4}},4}$
# 39    False                 4   ${\bf{x}}_{\beta \,{\bf{4}},5}$
# 6     False                 5   ${\bf{x}}_{\beta \,{\bf{5}},0}$
# 7     False                 5   ${\bf{x}}_{\beta \,{\bf{5}},1}$
# 8     False                 5   ${\bf{x}}_{\beta \,{\bf{5}},2}$
# 9     False                 5   ${\bf{x}}_{\beta \,{\bf{5}},3}$
# 10    False                 5   ${\bf{x}}_{\beta \,{\bf{5}},4}$
# 41    False                 5   ${\bf{x}}_{\beta \,{\bf{5}},5}$
# 17    False                 6   ${\bf{x}}_{\beta \,{\bf{6}},0}$

# %%
# %debug
# Out:
# > /home/miguel/PycharmProjects/gempy/gempy/data_management.py(155)calculate_orientations()
#     153         Calculate and update the orientation data (azimuth and dip) from gradients in the data frame.
#     154         """
# --> 155         self.orientations["dip"] = np.nan_to_num(np.arccos(self.orientations["G_z"] / self.orientations["polarity"]))
#     156
#     157         # TODO if this way to compute azimuth breaks there is in rgeomod=kml_to_plane line 170 a good way to do it
#
# ipdb> self.orientations["G_z"]
# 0    0.948683
# 1    0.316229
# Name: G_z, dtype: object
# ipdb> self.orientations["G_z"].astype(float)
# 0    0.948683
# 1    0.316229
# Name: G_z, dtype: float64
# ipdb> self.orientations
#         X     Y       Z       G_x    G_y       G_z     dip azimuth polarity  \
# 0    1450  1000   -1150  0.316229  1e-07  0.948683  18.435      90        1
# 1  917.45  1000 -1135.4 -0.948683  1e-07  0.316229  71.565     270        1
#
#    formation         series  order_series  isFault  formation_number  \
# 0  Reservoir  Default serie             1    False                 1
# 1  MainFault  Default serie             1    False                 2
#
#                        annotations
# 0  ${\bf{x}}_{\beta \,{\bf{1}},0}$
# 1  ${\bf{x}}_{\beta \,{\bf{2}},0}$
# ipdb> self.orientations.dtypes
# X                   object
# Y                   object
# Z                   object
# G_x                 object
# G_y                 object
# G_z                 object
# dip                 object
# azimuth             object
# polarity            object
# formation           object
# series              object
# order_series         int64
# isFault               bool
# formation_number     int64
# annotations         object
# dtype: object
# ipdb> exit

# %%
gp.get_data(geo_data)
# Out:
#               G_x  G_y  G_z     X     Y     Z azimuth  dip  formation  \
# interfaces 0  NaN  NaN  NaN   300  1000  -950     NaN  NaN  Reservoir
#            1  NaN  NaN  NaN  2000  1000 -1275     NaN  NaN  Reservoir
#            2  NaN  NaN  NaN   NaN   NaN   NaN     NaN  NaN   basement
#
#              polarity         series
# interfaces 0      NaN  Default serie
#            1      NaN  Default serie
#            2      NaN  Default serie
