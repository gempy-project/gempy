# %% [markdown]
# # Example for hillshading / Schummerung

# %%
import numpy as np
from matplotlib.colors import LightSource
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1, 1, 101)
xx = np.outer(x, x)
z = np.sinc(xx)

# %%
plt.imshow(z)

# %%
azdeg = 155. # azimuth of light source
altdeg = 20. # altitude of light source
ve = 1. # vertical exaggeration
ls = LightSource(azdeg=azdeg, altdeg=altdeg)
rgb = ls.shade(z, cmap=plt.cm.gray, vert_exag=ve, blend_mode='hsv')
plt.imshow(rgb, origin='lower left', aspect='auto')

# %%
plt.imshow(z)
plt.imshow(rgb, alpha=0.4)
