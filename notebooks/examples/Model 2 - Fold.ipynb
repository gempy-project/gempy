# %% [markdown]
# # Model 2 - Anticline

# %% [markdown]
# A simple anticline structure. We start by importing the necessary dependencies:

# %%
# These two lines are necessary only if GemPy is not installed
import sys, os
sys.path.append("../..")

# Importing GemPy
import gempy as gp

# Embedding matplotlib figures in the notebooks
# %matplotlib inline

# Importing auxiliary libraries
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ../..\gempy\posterior_analysis.py:28: UserWarning: pymc (v3) package is not installed. No support for stochastic simulation posterior analysis.
#   warnings.warn("pymc (v3) package is not installed. No support for stochastic simulation posterior analysis.")

# %% [markdown]
# Creating the model by importing the input data and displaying it:

# %%
geo_data = gp.create_data([0,1000,0,1000,0,1000],resolution=[50,50,50], 
                        path_o = os.pardir+"/examples/input_data/model2_orientations.csv",
                        path_i = os.pardir+"/examples/input_data/model2_surface_points.csv")
# Out:
# ../..\gempy\data_management.py:1267: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   values = np.vstack(map(np.ravel, g)).T.astype("float32")

# %%
geo_data.get_data()
# Out:
#                       X      Y      Z formation          series  \
# interfaces   0      0.0  100.0  200.0     rock1  Default series
#              15  1000.0  100.0  200.0     rock1  Default series
#              17  1000.0  900.0  200.0     rock1  Default series
#              16  1000.0  500.0  200.0     rock1  Default series
#              2      0.0  900.0  200.0     rock1  Default series
#              3    400.0  100.0  600.0     rock1  Default series
#              4    400.0  500.0  600.0     rock1  Default series
#              5    400.0  900.0  600.0     rock1  Default series
#              6    200.0  100.0  400.0     rock1  Default series
#              7    200.0  500.0  400.0     rock1  Default series
#              1      0.0  500.0  200.0     rock1  Default series
#              8    200.0  900.0  400.0     rock1  Default series
#              10   800.0  500.0  400.0     rock1  Default series
#              11   800.0  900.0  400.0     rock1  Default series
#              12   600.0  100.0  600.0     rock1  Default series
#              13   600.0  500.0  600.0     rock1  Default series
#              14   600.0  900.0  600.0     rock1  Default series
#              9    800.0  100.0  400.0     rock1  Default series
#              23  1000.0  900.0  400.0     rock2  Default series
#              24   400.0  100.0  800.0     rock2  Default series
#              25   400.0  500.0  800.0     rock2  Default series
#              19     0.0  500.0  400.0     rock2  Default series
#              20     0.0  900.0  400.0     rock2  Default series
#              26   400.0  900.0  800.0     rock2  Default series
#              29   200.0  900.0  600.0     rock2  Default series
#              30   600.0  100.0  800.0     rock2  Default series
#              31   600.0  500.0  800.0     rock2  Default series
#              32   600.0  900.0  800.0     rock2  Default series
#              33   800.0  100.0  600.0     rock2  Default series
#              27   200.0  100.0  600.0     rock2  Default series
#              28   200.0  500.0  600.0     rock2  Default series
#              18     0.0  100.0  400.0     rock2  Default series
#              34   800.0  500.0  600.0     rock2  Default series
#              22  1000.0  500.0  400.0     rock2  Default series
#              35   800.0  900.0  600.0     rock2  Default series
#              21  1000.0  100.0  400.0     rock2  Default series
#              36     0.0    0.0    0.0  basement  Default series
# orientations 1    500.0  500.0  620.0     rock1  Default series
#              0    500.0  500.0  820.0     rock2  Default series
#
#                  formation_number  order_series  isFault           G_x  \
# interfaces   0                  1             1    False           NaN
#              15                 1             1    False           NaN
#              17                 1             1    False           NaN
#              16                 1             1    False           NaN
#              2                  1             1    False           NaN
#              3                  1             1    False           NaN
#              4                  1             1    False           NaN
#              5                  1             1    False           NaN
#              6                  1             1    False           NaN
#              7                  1             1    False           NaN
#              1                  1             1    False           NaN
#              8                  1             1    False           NaN
#              10                 1             1    False           NaN
#              11                 1             1    False           NaN
#              12                 1             1    False           NaN
#              13                 1             1    False           NaN
#              14                 1             1    False           NaN
#              9                  1             1    False           NaN
#              23                 2             1    False           NaN
#              24                 2             1    False           NaN
#              25                 2             1    False           NaN
#              19                 2             1    False           NaN
#              20                 2             1    False           NaN
#              26                 2             1    False           NaN
#              29                 2             1    False           NaN
#              30                 2             1    False           NaN
#              31                 2             1    False           NaN
#              32                 2             1    False           NaN
#              33                 2             1    False           NaN
#              27                 2             1    False           NaN
#              28                 2             1    False           NaN
#              18                 2             1    False           NaN
#              34                 2             1    False           NaN
#              22                 2             1    False           NaN
#              35                 2             1    False           NaN
#              21                 2             1    False           NaN
#              36                 3             1    False           NaN
# orientations 1                  1             1    False  1.000000e-12
#              0                  2             1    False  1.000000e-12
#
#                           G_y  G_z  dip  azimuth  polarity
# interfaces   0            NaN  NaN  NaN      NaN       NaN
#              15           NaN  NaN  NaN      NaN       NaN
#              17           NaN  NaN  NaN      NaN       NaN
#              16           NaN  NaN  NaN      NaN       NaN
#              2            NaN  NaN  NaN      NaN       NaN
#              3            NaN  NaN  NaN      NaN       NaN
#              4            NaN  NaN  NaN      NaN       NaN
#              5            NaN  NaN  NaN      NaN       NaN
#              6            NaN  NaN  NaN      NaN       NaN
#              7            NaN  NaN  NaN      NaN       NaN
#              1            NaN  NaN  NaN      NaN       NaN
#              8            NaN  NaN  NaN      NaN       NaN
#              10           NaN  NaN  NaN      NaN       NaN
#              11           NaN  NaN  NaN      NaN       NaN
#              12           NaN  NaN  NaN      NaN       NaN
#              13           NaN  NaN  NaN      NaN       NaN
#              14           NaN  NaN  NaN      NaN       NaN
#              9            NaN  NaN  NaN      NaN       NaN
#              23           NaN  NaN  NaN      NaN       NaN
#              24           NaN  NaN  NaN      NaN       NaN
#              25           NaN  NaN  NaN      NaN       NaN
#              19           NaN  NaN  NaN      NaN       NaN
#              20           NaN  NaN  NaN      NaN       NaN
#              26           NaN  NaN  NaN      NaN       NaN
#              29           NaN  NaN  NaN      NaN       NaN
#              30           NaN  NaN  NaN      NaN       NaN
#              31           NaN  NaN  NaN      NaN       NaN
#              32           NaN  NaN  NaN      NaN       NaN
#              33           NaN  NaN  NaN      NaN       NaN
#              27           NaN  NaN  NaN      NaN       NaN
#              28           NaN  NaN  NaN      NaN       NaN
#              18           NaN  NaN  NaN      NaN       NaN
#              34           NaN  NaN  NaN      NaN       NaN
#              22           NaN  NaN  NaN      NaN       NaN
#              35           NaN  NaN  NaN      NaN       NaN
#              21           NaN  NaN  NaN      NaN       NaN
#              36           NaN  NaN  NaN      NaN       NaN
# orientations 1   1.000000e-12  1.0  0.0     90.0       1.0
#              0   1.000000e-12  1.0  0.0     90.0       1.0

# %% [markdown]
# Setting and ordering the units and series:

# %%
gp.set_series(geo_data, {"Strat_Series": ('rock2','rock1'),"Basement_Series":('basement')},
              order_series = ['Strat_Series','Basement_Series'],
              order_formations=np.array(['rock2','rock1','basement']), verbose=0)

# %%
#%matplotlib inline
gp.get_sequential_pile(geo_data)

# %%
# %matplotlib inline
#gp.plotting.plot_data(geo_data, direction='y')

# %% [markdown]
# Calculating the model:

# %%
interp_data = gp.InterpolatorData(geo_data, u_grade=[1], output='geology', compile_theano=True, theano_optimizer='fast_compile')
# Out:
# Compiling theano function...
# Compilation Done!
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float32
# Number of faults:  0

# %%
lith_block, fault_block = gp.compute_model(interp_data)
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\theano\tensor\subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]

# %% [markdown]
# Displaying the result in y and x direction:

# %%
# %matplotlib inline
gp.plotting.plot_section(geo_data, lith_block[0], cell_number=25,
                         direction='y', plot_data=True)

# %%
# %matplotlib inline
gp.plotting.plot_section(geo_data, lith_block[0], cell_number=25,
                         direction='x', plot_data=True)
